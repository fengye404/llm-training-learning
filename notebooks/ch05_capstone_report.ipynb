# %% [markdown]
# # 第 5 章 Notebook：自动生成学习报告
#
# 目标：把前面章节结果沉淀成可复盘报告。

# %%
import subprocess, sys
subprocess.run([sys.executable, 'projects/project-04-capstone/build_learning_report.py'], check=True)

# %%
from pathlib import Path
print(Path('projects/project-04-capstone/learning_report.md').read_text(encoding='utf-8'))

# %% [markdown]
# ## 下一步
# 把 `EXPERIMENTS` 替换为你真实训练数据，再重新生成报告。
