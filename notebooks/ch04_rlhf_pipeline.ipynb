# %% [markdown]
# # 第 4 章 Notebook：RLHF 流水线
#
# 目标：看懂生成 -> 打分 -> 更新的闭环。

# %% [markdown]
# ## 你将看到什么
# - 平均期望奖励逐步上升
# - 每个问题最终偏向高奖励策略

# %%
import subprocess, sys
subprocess.run([sys.executable, 'projects/project-03-rlhf-pipeline/rlhf_pipeline_demo.py'], check=True)

# %% [markdown]
# ## 对照讲义
# - `projects/project-03-rlhf-pipeline/GUIDE_STEP_BY_STEP.md`
