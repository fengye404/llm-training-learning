# %% [markdown]
# # 第 1 章 Notebook：训练最小闭环
#
# 目标：看懂 "预测 -> 误差 -> 梯度 -> 更新" 这 4 步。

# %% [markdown]
# ## 你将看到什么
# - `loss` 逐步下降
# - `w` 逐步接近 2，`b` 逐步接近 1
# - `x=3` 的预测值接近 7

# %%
from pathlib import Path
import subprocess, sys

ROOT = Path.cwd()
if not (ROOT / 'projects').exists():
    if (ROOT.parent / 'projects').exists():
        ROOT = ROOT.parent
    else:
        raise RuntimeError(f'未找到项目根目录（应包含 projects/ 目录），当前目录: {Path.cwd()}')

print('使用项目目录:', ROOT)
subprocess.run([sys.executable, 'projects/project-00-foundation/toy_autograd_train.py'], check=True, cwd=ROOT)
# Out:
# /opt/anaconda3/bin/python: can't open file '/Users/fengye/workspace/llm-training-learning/notebooks/projects/project-00-foundation/toy_autograd_train.py': [Errno 2] No such file or directory
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[1], line 2
#       1 import subprocess, sys
# ----> 2 subprocess.run([sys.executable, 'projects/project-00-foundation/toy_autograd_train.py'], check=True)
#
# File /opt/anaconda3/lib/python3.12/subprocess.py:571, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     569     retcode = process.poll()
#     570     if check and retcode:
# --> 571         raise CalledProcessError(retcode, process.args,
#     572                                  output=stdout, stderr=stderr)
#     573 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# ...

# %% [markdown]
# ## 对照讲义
# - 10 行讲义：`projects/project-00-foundation/GUIDE_STEP_BY_STEP.md`
