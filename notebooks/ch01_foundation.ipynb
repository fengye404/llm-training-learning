# %% [markdown]
# # 第 1 章 Notebook：训练最小闭环
#
# 目标：看懂 "预测 -> 误差 -> 梯度 -> 更新" 这 4 步。

# %% [markdown]
# ## 你将看到什么
# - `loss` 逐步下降
# - `w` 逐步接近 2，`b` 逐步接近 1
# - `x=3` 的预测值接近 7

# %%
import subprocess, sys
subprocess.run([sys.executable, 'projects/project-00-foundation/toy_autograd_train.py'], check=True)

# %% [markdown]
# ## 对照讲义
# - 10 行讲义：`projects/project-00-foundation/GUIDE_STEP_BY_STEP.md`
